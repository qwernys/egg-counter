# %%
from ultralytics import YOLO

# %%
model = YOLO("./runs/detect/egg-counter/weights/best.pt")

# %%
results = model("EggCounterDatasetV2/test/images/frame_sr-3_670_jpg.rf.c129962351649214ba19a992dc38b8be.jpg")

from IPython.display import Image, display
results[0].save(filename="output.jpg")
display(Image(filename="output.jpg"))
# Out:
# image 1/1 c:\Users\kevin\Desktop\Egg-Detector\EggCounterDatasetV2\test\images\frame_sr-3_670_jpg.rf.c129962351649214ba19a992dc38b8be.jpg: 384x640 8 Eggs, 42.7ms
# Speed: 2.4ms preprocess, 42.7ms inference, 55.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
RTSP_URL = 'rtsp://admin:Egg%21Camera1@192.168.68.70:554/h264Preview_01_main'

# Run inference and save annotated video
results = model.predict(
    source=RTSP_URL,   # your input video
    save=True,                         # save the video with boxes
    save_txt=False,                    # optionally save txt results
    conf=0.25,                         # confidence threshold
    vid_stride=1                       # run on every frame
)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/8371) c:\Users\kevin\Desktop\Egg-Detector\eggs.mp4: 384x640 4 Eggs, 118.8ms
# video 1/1 (frame 2/8371) c:\Users\kevin\Desktop\Egg-Detector\eggs.mp4: 384x640 5 Eggs, 42.0ms
# video 1/1 (frame 3/8371) c:\Users\kevin\Desktop\Egg-Detector\eggs.mp4: 384x640 4 Eggs, 7.0ms
# video 1/1 (frame 4/8371) c:\Users\kevin\Desktop\Egg-Detector\eggs.mp4: 384x640 4 Eggs, 7.0ms
# ...
